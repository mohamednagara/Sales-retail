# %% [markdown]
# # GDP PROJECT

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Download database 

df = pd.read_csv('GDP.csv')
df.head()
# Out:
#                        Country Country Code          1960          1961  \
# 0                        Aruba          ABW           NaN           NaN
# 1  Africa Eastern and Southern          AFE  2.112502e+10  2.161623e+10
# 2                  Afghanistan          AFG  5.377778e+08  5.488889e+08
# 3   Africa Western and Central          AFW  1.044764e+10  1.117321e+10
# 4                       Angola          AGO           NaN           NaN
#
#            1962          1963          1964          1965          1966  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.350628e+10  2.804836e+10  2.592067e+10  2.947210e+10  3.201437e+10
# 2  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09
# 3  1.199053e+10  1.272769e+10  1.389811e+10  1.492979e+10  1.591084e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            1967  ...          2013          2014          2015          2016  \
# ...

# %%
df.shape
# Out:
# (266, 65)

# %%
df.dtypes.value_counts()
# Out:
# float64    63
# object      2
# dtype: int64

# %% [markdown]
# # Visualize missing values using a heatmap
#
# ### This technique allows me to visualize all the NaN values in my dataframe.

# %%
# Create a 20x10-inch figure
plt.figure(figsize=(20, 10))

# Visualize missing values using a heatmap
sns.heatmap(df.isna(), cbar=False)

# Calculate and sort missing value percentages
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# Country         0.000000
# Country Code    0.000000
# 2014            0.022556
# 2011            0.022556
# 2013            0.026316
# 2018            0.030075
# 2017            0.030075
# 2016            0.030075
# 2015            0.030075
# 2012            0.030075
# 2020            0.033835
# 2019            0.033835
# 2010            0.033835
# 2008            0.037594
# 2009            0.037594
# 2007            0.041353
# 2006            0.041353
# 2005            0.045113
# 2004            0.045113
# 2003            0.045113
# 2002            0.045113
# 2021            0.056391
# 2001            0.063910
# 2000            0.071429
# 1999            0.086466
# 1998            0.090226
# 1995            0.097744
# 1997            0.097744
# 1996            0.097744
# 2022            0.124060
# 1994            0.131579
# 1993            0.139098
# 1992            0.146617
# 1990            0.150376
# 1991            0.150376
# 1988            0.210526
# 1989            0.210526
# ...

# %% [markdown]
# # Cleaning Data

# %%
# Remove rows with any missing values from the DataFrame 'df'
df = df.dropna()

# Remove the 'Country Code' column from the DataFrame 'df'
df = df.drop(['Country Code'], axis=1)

# Display the shape (number of rows and columns) of the modified DataFrame 'df'
df.shape
# Out:
# (122, 64)

# %%
df.head()
# Out:
#                         Country          1960          1961          1962  \
# 1   Africa Eastern and Southern  2.112502e+10  2.161623e+10  2.350628e+10
# 3    Africa Western and Central  1.044764e+10  1.117321e+10  1.199053e+10
# 13                    Australia  1.860656e+10  1.968288e+10  1.992256e+10
# 14                      Austria  6.592694e+09  7.311750e+09  7.756110e+09
# 16                      Burundi  1.960000e+08  2.030000e+08  2.135000e+08
#
#             1963          1964          1965          1966          1967  \
# 1   2.804836e+10  2.592067e+10  2.947210e+10  3.201437e+10  3.326951e+10
# 3   1.272769e+10  1.389811e+10  1.492979e+10  1.591084e+10  1.451058e+10
# 13  2.153984e+10  2.380112e+10  2.597616e+10  2.730784e+10  3.044272e+10
# 14  8.374175e+09  9.169984e+09  9.994071e+09  1.088768e+10  1.157943e+10
# 16  2.327500e+08  2.607500e+08  1.589950e+08  1.654446e+08  1.782971e+08
#
#             1968  ...          2013          2014          2015          2016  \
# ...

# %%
# Obtain a list containing all the data from the 'Country' column
country_list = df['Country'].tolist()

# Display the list
print(country_list)
# Out:
# ['Africa Eastern and Southern', 'Africa Western and Central', 'Australia', 'Austria', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bahamas, The', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Botswana', 'Central African Republic', 'Canada', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Costa Rica', 'Caribbean small states', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific', 'Ecuador', 'Euro area', 'Spain', 'Finland', 'Fiji', 'France', 'Gabon', 'United Kingdom', 'Ghana', 'Greece', 'Guatemala', 'Guyana', 'High income', 'Hong Kong SAR, China', 'Honduras', 'Heavily indebted poor countries (HIPC)', 'Haiti', 'IBRD only', 'IDA & IBRD total', 'IDA total', 'IDA blend', 'IDA only', 'India', 'Ireland', 'Iceland', 'Italy', 'Jamaica', 'Japan', 'Kenya', 'St. Kitts and Nevis', 'Korea, Rep.', 'Latin America & Caribbean (excluding high income)', 'Latin Ameri
# ...

# %% [markdown]
# # Transpose the DataFrame, swapping columns and rows

# %%
# Set the "Country" column as the index of the DataFrame 'df'
df.set_index('Country', inplace=True)

# %%
df.head()
# Out:
#                                      1960          1961          1962  \
# Country
# Africa Eastern and Southern  2.112502e+10  2.161623e+10  2.350628e+10
# Africa Western and Central   1.044764e+10  1.117321e+10  1.199053e+10
# Australia                    1.860656e+10  1.968288e+10  1.992256e+10
# Austria                      6.592694e+09  7.311750e+09  7.756110e+09
# Burundi                      1.960000e+08  2.030000e+08  2.135000e+08
#
#                                      1963          1964          1965  \
# Country
# Africa Eastern and Southern  2.804836e+10  2.592067e+10  2.947210e+10
# Africa Western and Central   1.272769e+10  1.389811e+10  1.492979e+10
# Australia                    2.153984e+10  2.380112e+10  2.597616e+10
# Austria                      8.374175e+09  9.169984e+09  9.994071e+09
# Burundi                      2.327500e+08  2.607500e+08  1.589950e+08
#
#                                      1966          1967          1968  \
# Country
# ...

# %%
# Transpose the DataFrame to reverse the columns and rows
df = df.T

# %%
df.head()
# Out:
# Country  Africa Eastern and Southern  Africa Western and Central  \
# 1960                    2.112502e+10                1.044764e+10
# 1961                    2.161623e+10                1.117321e+10
# 1962                    2.350628e+10                1.199053e+10
# 1963                    2.804836e+10                1.272769e+10
# 1964                    2.592067e+10                1.389811e+10
#
# Country     Australia       Austria      Burundi       Belgium        Benin  \
# 1960     1.860656e+10  6.592694e+09  195999989.8  1.165872e+10  226195578.1
# 1961     1.968288e+10  7.311750e+09  202999991.8  1.240015e+10  235668220.9
# 1962     1.992256e+10  7.756110e+09  213500005.8  1.326402e+10  236434954.3
# 1963     2.153984e+10  8.374175e+09  232749997.8  1.426002e+10  253927697.6
# 1964     2.380112e+10  9.169984e+09  260750007.7  1.596011e+10  269819005.8
#
# Country  Burkina Faso    Bangladesh  Bahamas, The  ...       Turkiye  \
# ...

# %% [markdown]
# # Creating a second dataframe with geographical regions, economic groups, or demographic classifications.
#
# ### This allows me to sort between countries and world regions in order to perform more tailored analyses.

# %%
import pandas as pd

# List of countries to exclude
pays_a_exclure = [
    'Australia', 'Austria', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bahamas, The', 'Belize', 
    'Bermuda', 'Bolivia', 'Brazil', 'Botswana', 'Central African Republic', 'Canada', 'Chile', 'China', 
    "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Costa Rica', 'Caribbean small states', 
    'Dominican Republic', 'Algeria', 'Spain', 'Finland', 'Fiji', 'France', 'Gabon', 'United Kingdom', 'Ghana', 'Greece', 
    'Guatemala', 'Guyana', 'Hong Kong SAR, China', 'Honduras', 'Haiti', 'India', 'Ireland', 'Iceland', 'Italy', 
    'Jamaica', 'Japan', 'Kenya', 'St. Kitts and Nevis', 'Korea, Rep.', 'Sri Lanka', 'Lesotho', 'Luxembourg', 'Morocco', 
    'Madagascar', 'Mexico', 'Netherlands', 'Norway', 'Nepal', 'Pakistan', 'Panama', 'Peru', 'Philippines', 
    'Papua New Guinea', 'Puerto Rico', 'Portugal', 'Rwanda', 'South Asia', 'Sudan', 'Senegal', 'Singapore', 
    'Sierra Leone', 'Suriname', 'Sweden', 'Eswatini', 'Seychelles', 'Chad', 'Togo', 'Thailand', 'Trinidad and Tobago', 
    'Turkiye', 'Uganda', 'Uruguay', 'United States', 'St. Vincent and the Grenadines', 'South Africa', 'Zambia', 
    'Zimbabwe','Niger', 'Nigeria', 'Nicaragua','Malaysia'
]

# Create a second DataFrame (df2) by excluding the specified columns
df2 = df.drop(columns=pays_a_exclure)

df2.head()
# Out:
# Country  Africa Eastern and Southern  Africa Western and Central  \
# 1960                    2.112502e+10                1.044764e+10
# 1961                    2.161623e+10                1.117321e+10
# 1962                    2.350628e+10                1.199053e+10
# 1963                    2.804836e+10                1.272769e+10
# 1964                    2.592067e+10                1.389811e+10
#
# Country  East Asia & Pacific (excluding high income)  \
# 1960                                    8.132635e+10
# 1961                                    7.159626e+10
# 1962                                    6.538008e+10
# 1963                                    7.082595e+10
# 1964                                    8.174206e+10
#
# Country  Early-demographic dividend  East Asia & Pacific       Ecuador  \
# 1960                   1.503254e+11         1.546356e+11  2.069465e+09
# 1961                   1.599404e+11         1.551715e+11  1.753850e+09
# ...

# %% [markdown]
# # DataFrame with individual countries

# %%
# List of column names to exclude
columns_to_exclude = [
    'Africa Eastern and Southern', 'Africa Western and Central', 'Early-demographic dividend',
    'East Asia & Pacific (excluding high income)', 'East Asia & Pacific', 'Euro area', 'High income',
    'Heavily indebted poor countries (HIPC)', 'IDA & IBRD total', 'IDA total', 'IDA blend', 'IDA only',
    'Latin America & Caribbean (excluding high income)', 'Latin America & Caribbean', 'Lower middle income',
    'Low & middle income', 'Late-demographic dividend', 'Middle income', 'North America', 'OECD members',
    'Pre-demographic dividend', 'Post-demographic dividend', 'South Asia', 'South Asia (IDA & IBRD)',
    'Sub-Saharan Africa (excluding high income)', 'Sub-Saharan Africa', 'East Asia & Pacific (IDA & IBRD countries)',
    'Latin America & the Caribbean (IDA & IBRD countries)', 'Sub-Saharan Africa (IDA & IBRD countries)',
    'World', 'Upper middle income'
]

# Create a DataFrame df2 by excluding the specified columns
df = df.drop(columns=columns_to_exclude)

# Display the first few rows of df
df.head()
# Out:
# Country     Australia       Austria      Burundi       Belgium        Benin  \
# 1960     1.860656e+10  6.592694e+09  195999989.8  1.165872e+10  226195578.1
# 1961     1.968288e+10  7.311750e+09  202999991.8  1.240015e+10  235668220.9
# 1962     1.992256e+10  7.756110e+09  213500005.8  1.326402e+10  236434954.3
# 1963     2.153984e+10  8.374175e+09  232749997.8  1.426002e+10  253927697.6
# 1964     2.380112e+10  9.169984e+09  260750007.7  1.596011e+10  269819005.8
#
# Country  Burkina Faso    Bangladesh  Bahamas, The       Belize       Bermuda  \
# 1960      330442815.3  4.274894e+09   169803921.6  28072478.06  8.446665e+07
# 1961      350247234.8  4.817580e+09   190098039.2  29964999.96  8.924999e+07
# 1962      379567099.7  5.081413e+09   212254902.0  31857591.85  9.414999e+07
# 1963      394040667.6  5.319458e+09   237745098.0  33750113.74  9.636665e+07
# 1964      410321644.8  5.386055e+09   266666666.7  36194586.18  1.075667e+08
#
# ...

# %% [markdown]
# # Format the numbers with two decimal places

# %%
import pandas as pd

# Define a function to format numbers with two decimal places
def format_number(x):
    if isinstance(x, (int, float)):
        return "{:.2f}".format(x)
    else:
        return x

# Apply the formatting to all cells in the DataFrame
df = df.applymap(format_number)

# %%
df.head()
# Out:
# Country       Australia        Austria       Burundi         Belgium  \
# 1960     18606562979.00  6592693841.00  195999989.80  11658722591.00
# 1961     19682883152.00  7311749633.00  202999991.80  12400145222.00
# 1962     19922563190.00  7756110210.00  213500005.80  13264015675.00
# 1963     21539843449.00  8374175258.00  232749997.80  14260017387.00
# 1964     23801123811.00  9169983886.00  260750007.70  15960106681.00
#
# Country         Benin  Burkina Faso     Bangladesh  Bahamas, The       Belize  \
# 1960     226195578.10  330442815.30  4274893913.00  169803921.60  28072478.06
# 1961     235668220.90  350247234.80  4817580184.00  190098039.20  29964999.96
# 1962     236434954.30  379567099.70  5081413340.00  212254902.00  31857591.85
# 1963     253927697.60  394040667.60  5319458351.00  237745098.00  33750113.74
# 1964     269819005.80  410321644.80  5386054619.00  266666666.70  36194586.18
#
# Country       Bermuda  ...       Thailand Trinidad and Tobago         Turkiye  \
# ...

# %%
import pandas as pd

# Define a function to format numbers with two decimal places
def format_number(x):
    if isinstance(x, (int, float)):
        return "{:.2f}".format(x)
    else:
        return x

# Apply the formatting to all cells in the DataFrame 'df2'
df2 = df2.applymap(format_number)

# %%
df2.head()
# Out:
# Country Africa Eastern and Southern Africa Western and Central  \
# 1960                 21125015452.00             10447637853.00
# 1961                 21616228139.00             11173212080.00
# 1962                 23506279900.00             11990534018.00
# 1963                 28048360188.00             12727688165.00
# 1964                 25920665260.00             13898109284.00
#
# Country East Asia & Pacific (excluding high income)  \
# 1960                                 81326348986.00
# 1961                                 71596255522.00
# 1962                                 65380076110.00
# 1963                                 70825945773.00
# 1964                                 81742063327.00
#
# Country Early-demographic dividend East Asia & Pacific        Ecuador  \
# 1960               150325406858.00     154635572037.00  2069465326.00
# 1961               159940391122.00     155171539972.00  1753850417.00
# ...

# %%
df.shape
# Out:
# (63, 91)

# %%
df2.shape
# Out:
# (63, 35)

# %%
print(df2.columns)
# Out:
# Index(['Africa Eastern and Southern', 'Africa Western and Central',
#        'East Asia & Pacific (excluding high income)',
#        'Early-demographic dividend', 'East Asia & Pacific', 'Ecuador',
#        'Euro area', 'High income', 'Heavily indebted poor countries (HIPC)',
#        'IBRD only', 'IDA & IBRD total', 'IDA total', 'IDA blend', 'IDA only',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & Caribbean', 'Lower middle income',
#        'Low & middle income', 'Late-demographic dividend', 'Middle income',
#        'Malaysia', 'North America', 'Niger', 'Nigeria', 'Nicaragua',
#        'OECD members', 'Pre-demographic dividend', 'Post-demographic dividend',
#        'Sub-Saharan Africa (excluding high income)', 'Sub-Saharan Africa',
#        'East Asia & Pacific (IDA & IBRD countries)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'South Asia (IDA & IBRD)', 'Sub-Saharan Africa (IDA & IBRD countries)',
# ...

# %%
print(df.columns)
# Out:
# Index(['Australia', 'Austria', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bahamas, The', 'Belize', 'Bermuda', 'Bolivia', 'Brazil',
#        'Botswana', 'Central African Republic', 'Canada', 'Chile', 'China',
#        'Cote d'Ivoire', 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Colombia', 'Costa Rica', 'Caribbean small states',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Spain', 'Finland', 'Fiji',
#        'France', 'Gabon', 'United Kingdom', 'Ghana', 'Greece', 'Guatemala',
#        'Guyana', 'Hong Kong SAR, China', 'Honduras', 'Haiti', 'IBRD only',
#        'India', 'Ireland', 'Iceland', 'Italy', 'Jamaica', 'Japan', 'Kenya',
#        'St. Kitts and Nevis', 'Korea, Rep.', 'Sri Lanka', 'Lesotho',
#        'Luxembourg', 'Morocco', 'Madagascar', 'Mexico', 'Malaysia', 'Niger',
#        'Nigeria', 'Nicaragua', 'Netherlands', 'Norway', 'Nepal', 'Pakistan',
#        'Panama', 'Peru', 'Philippines', 'Papua New Guinea', 'Puerto Rico',
# ...

# %%
df = df.drop('IBRD only', axis=1)

# %% [markdown]
# ## The global GDP has evolved over time from 1960 to 2022, showing changes and fluctuations in the world's economic output.

# %%
# Convert the 'World' column to numeric, coercing errors
df2['World'] = pd.to_numeric(df2['World'], errors='coerce')

# Check if the conversion was successful
if not df2['World'].isnull().any():
    # Round values to two decimal places (adjust as needed)
    df2['World'] = df2['World'].round(2)

    # Divide all values by one billion to simplify the y-axis (display in billions of dollars)
    df2['World'] = df2['World'] / 1e9  # Divide by 1 billion to display in billions of dollars

    # Create a plot using the index and the 'World' variable
    plt.figure(figsize=(40, 12))
    plt.plot(df2.index, df2['World'], marker='o', linestyle='-')
    plt.title("Global GDP Evolution (1960-2022)")
    plt.xlabel("Year")
    plt.ylabel("Global GDP (in billions of dollars)")
    plt.grid(True)

    # Display the plot
    plt.show()
else:
    print("Data conversion failed. Please check the values in the 'World' column.")

# %% [markdown]
# It is possible to observe that the GDP experienced three periods of decline: in 2008 during the subprime crisis, in 2014, and in 2019 at the onset of the COVID-19 pandemic.
#
# Since 1960, it is noteworthy that the global Gross Domestic Product (GDP) has generally experienced continuous growth over the years, indicating an overall progression in the world economy during this period. This increase in global GDP over the years can be attributed to economic growth, globalization, technological advancements, urbanization, investments, and favorable economic policies.

# %%
# Create a new column 'Afrique' by combining 'Africa Eastern and Southern' and 'Africa Western and Central'
df2['Afrique'] = df2['Africa Eastern and Southern'] + df2['Africa Western and Central']

# Create a new column 'Asie' by using the 'East Asia & Pacific' column
df2['Asie'] = df2['East Asia & Pacific']

# Create a new column 'Amérique du Nord' by using the 'North America' column
df2['Amérique du Nord'] = df2['North America']

# Create a new column 'Amérique du Sud' by using the 'Latin America & Caribbean' column
df2['Amérique du Sud'] = df2['Latin America & Caribbean']

# Create a new column 'Europe' by using the 'Euro area' column
df2['Europe'] = df2['Euro area']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# The years will serve as the index
years = df2.index

# Create series for each continent
africa = df2['Afrique']
asia = df2['Asie']
north_america = df2['Amérique du Nord']
south_america = df2['Amérique du Sud']
europe = df2['Europe']

# Create a line plot with overlaid curves
plt.figure(figsize=(40, 20))

# Plot curves for each continent
plt.plot(years, africa, label='Africa')
plt.plot(years, asia, label='Asia')
plt.plot(years, north_america, label='North America')
plt.plot(years, south_america, label='South America')
plt.plot(years, europe, label='Europe')

# Add axis labels and a legend
plt.xlabel('Year')
plt.ylabel('Values')
plt.title('Evolution of Data by Continent Over the Years')
plt.legend()# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# After the subprime crisis, only Asia and North America maintained economic growth, while Europe and Africa experienced a period of economic stagnation. Asia and North America fared better in the subprime crisis due to their economic diversification, effective stimulus policies, relative financial stability, lower exposure to the U.S. real estate markets, and quick adaptation to new markets. In contrast, Europe was more severely affected due to its exposure to U.S. markets and slower policy responses. Africa, on the other hand, was less impacted due to its limited interconnectedness with global financial markets. For example, Asian economies like China swiftly redirected their production towards domestic and emerging markets, mitigating the impact of the subprime crisis. The United States implemented significant fiscal and monetary stimulus policies to stabilize their economy. Conversely, certain European countries were slower to respond, partly due to their exposure to U.S. real estate-related financial products.

# %% [markdown]
# ## Which regions of the world have experienced the fastest economic growth? The slowest?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the average economic growth for the continents North America and South America
average_growth_north = df2['North America'].mean()
average_growth_south = df2['South America'].mean()

# Create a line plot to compare the average economic growth of North America and South America
plt.figure(figsize=(30, 15))

# Line plot for North America in blue
plt.plot(df2.index, df2['North America'], label='North America', color='blue')

# Line plot for South America in red
plt.plot(df2.index, df2['South America'], label='South America', color='red')

plt.xlabel('Year')
plt.ylabel('Average Economic Growth')
plt.title('Comparison of Average Economic Growth between North America and South America')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The economic evolution of North America and South America has been marked by significant disparities in economic performance over the decades. North America, particularly the United States and Canada, has generally experienced robust economic growth with high living standards and economic diversification. This can be attributed in part to a more industrialized economy, relative political stability, and access to global markets.
#
# In contrast, South America has been more prone to economic fluctuations, experiencing intermittent periods of growth and economic crises. The reasons behind these disparities in performance include factors such as political and governance issues, dependence on commodities, economic inequalities, currency instabilities, and structural constraints.
#
# The dependence on commodities, including oil, minerals, and agricultural products, exposed many South American countries to the volatility of global prices, impacting their economic stability. Economic and social inequalities have also played a role in hindering inclusive growth in certain regions.
#
# Furthermore, governance problems, corruption, and political instability have hindered the implementation of coherent and effective economic policies. These combined factors have contributed to variations in economic performance between North America and South America.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Countries to plot
countries_to_plot = ['United States', 'China', 'India', 'Japan', 'United Kingdom', 'France']

# Restrict the DataFrame to the years from 2006 to 2022
df = df.loc['2006':'2022']

# Convert the data to numeric for the specified countries
for country in countries_to_plot:
    df[country] = pd.to_numeric(df[country], errors='coerce')

if not df[countries_to_plot].isnull().any().any():
    # Round values to two decimal places
    df[countries_to_plot] = df[countries_to_plot].round(2)

    # Divide all values by one billion to simplify the y-axis (display in billions of dollars)
    df[countries_to_plot] = df[countries_to_plot] / 1e9  # Divide by 1 billion to display in billions of dollars

    # Create a plot using the index and the variables for the countries
    plt.figure(figsize=(12, 6))

    for country in countries_to_plot:
        plt.plot(df.index, df[country], marker='o', linestyle='-', label=country)

    plt.title(f"GDP Evolution of Multiple Countries (2006-2022)")
    plt.xlabel("Year")
    plt.ylabel(f"GDP (in billions of dollars)")
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.grid(True)

    # Display the plot
    plt.tight_layout()
    plt.show()
else:
    print("Data conversion failed for at least one of the countries. Please check the values in the corresponding columns.")

# %% [markdown]
# Over the past few decades, the economic evolution of the United States and China has been marked by significant developments. The United States has maintained relatively stable economic growth, supported by dynamic sectors such as technology and energy. The American stock market has thrived, with technology giants becoming major players on the global stage. Accommodative fiscal and monetary policies have been adopted to boost growth.
#
# On the other hand, China has experienced rapid economic growth, becoming the world's second-largest economy. This has been driven by massive expansion in manufacturing, exports, and technological advancements. China has also launched the Belt and Road initiative to extend its global economic influence through massive investments in overseas infrastructure. Technological competition between China and the United States has intensified, especially in areas like 5G, artificial intelligence, and space exploration.
#
# Meanwhile, India is emerging as a rapidly growing economic power with a booming information technology sector and a young workforce. Japan, while facing demographic challenges and slower economic growth, remains a global leader in sectors such as automotive and electronics. France maintains a mixed economy with key sectors like aerospace and fashion. Lastly, the United Kingdom, post-Brexit, is seeking to redefine its international economic relations while preserving the City of London's position as a major financial center.
#
# These developments highlight diverse economic trajectories and challenges each country faces, with unique economic strengths and opportunities. The United States and China continue to be dominant economic players on the global stage, while other economic powers adapt to changing economic dynamics and seek new avenues for growth.

# %%
# Create a dictionary of countries and continents in English
pays_continent = {
    'Australia': 'Océanie',
    'Austria': 'Europe',
    'Burundi': 'Afrique',
    'Belgium': 'Europe',
    'Benin': 'Afrique',
    'Burkina Faso': 'Afrique',
    'Bangladesh': 'Asie',
    'Bahamas, The': 'Amérique du Nord',
    'Belize': 'Amérique du Nord',
    'Bermuda': 'Amérique du Nord',
    'Bolivia': 'Amérique du Sud',
    'Brazil': 'Amérique du Sud',
    'Botswana': 'Afrique',
    'Central African Republic': 'Afrique',
    'Canada': 'Amérique du Nord',
    'Chile': 'Amérique du Sud',
    'China': 'Asie',
    'Cote d\'Ivoire': 'Afrique',
    'Cameroon': 'Afrique',
    'Congo, Dem. Rep.': 'Afrique',
    'Congo, Rep.': 'Afrique',
    'Colombia': 'Amérique du Sud',
    'Costa Rica': 'Amérique centrale et Caraïbes',
    'Caribbean small states': 'Amérique centrale et Caraïbes',
    'Dominican Republic': 'Amérique centrale et Caraïbes',
    'Algeria': 'Afrique',
    'Ecuador': 'Amérique du Sud',
    'Spain': 'Europe',
    'Finland': 'Europe',
    'Fiji': 'Océanie',
    'France': 'Europe',
    'Gabon': 'Afrique',
    'United Kingdom': 'Europe',
    'Ghana': 'Afrique',
    'Greece': 'Europe',
    'Guatemala': 'Amérique du Sud',
    'Guyana': 'Amérique du Sud',
    'Hong Kong SAR, China': 'Asie',
    'Honduras': 'Amérique centrale et Caraïbes',
    'Haiti': 'Amérique du Sud',
    'IBRD only': 'Non spécifié',
    'India': 'Asie',
    'Ireland': 'Europe',
    'Iceland': 'Europe',
    'Italy': 'Europe',
    'Jamaica': 'Amérique du Sud',
    'Japan': 'Asie',
    'Kenya': 'Afrique',
    'St. Kitts and Nevis': 'Amérique du Sud',
    'Korea, Rep.': 'Asie',
    'Sri Lanka': 'Asie',
    'Lesotho': 'Afrique',
    'Luxembourg': 'Europe',
    'Morocco': 'Afrique',
    'Madagascar': 'Afrique',
    'Mexico': 'Amérique du Nord',
    'Malaysia': 'Asie',
    'Niger': 'Afrique',
    'Nigeria': 'Afrique',
    'Nicaragua': 'Amérique centrale et Caraïbes',
    'Netherlands': 'Europe',
    'Norway': 'Europe',
    'Nepal': 'Asie',
    'Pakistan': 'Asie',
    'Panama': 'Amérique centrale et Caraïbes',
    'Peru': 'Amérique du Sud',
    'Philippines': 'Asie',
    'Papua New Guinea': 'Océanie',
    'Puerto Rico': 'Amérique du Nord',
    'Portugal': 'Europe',
    'Rwanda': 'Afrique',
    'Sudan': 'Afrique',
    'Senegal': 'Afrique',
    'Singapore': 'Asie',
    'Sierra Leone': 'Afrique',
    'Suriname': 'Amérique du Sud',
    'Sweden': 'Europe',
    'Eswatini': 'Afrique',
    'Seychelles': 'Afrique',
    'Chad': 'Afrique',
    'Togo': 'Afrique',
    'Thailand': 'Asie',
    'Trinidad and Tobago': 'Amérique du Sud',
    'Turkey': 'Asie',
    'Uganda': 'Afrique',
    'Uruguay': 'Amérique du Sud',
    'United States': 'Amérique du Nord',
    'St. Vincent and the Grenadines': 'Amérique du Sud',
    'South Africa': 'Afrique',
    'Zambia': 'Afrique',
    'Zimbabwe': 'Afrique',
}

# Function to get the list of countries by continent
def pays_par_continent(continent):
    pays_du_continent = []
    for pays, cont in pays_continent.items():
        if cont == continent:
            pays_du_continent.append(pays)
    return pays_du_continent

# Examples of using the functions
pays_europeens = pays_par_continent('Europe')
print("Pays en Europe :", pays_europeens)

pays_americains_du_sud = pays_par_continent('Amérique du Sud')
print("Pays en Amérique du Sud :", pays_americains_du_sud)

pays_asiatiques = pays_par_continent('Asie')
print("Pays en Asie :", pays_asiatiques)

pays_africains = pays_par_continent('Afrique')
print("Pays en Afrique :", pays_africains)
# Out:
# Pays en Europe : ['Austria', 'Belgium', 'Spain', 'Finland', 'France', 'United Kingdom', 'Greece', 'Ireland', 'Iceland', 'Italy', 'Luxembourg', 'Netherlands', 'Norway', 'Portugal', 'Sweden']
# Pays en Amérique du Sud : ['Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guatemala', 'Guyana', 'Haiti', 'Jamaica', 'St. Kitts and Nevis', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'St. Vincent and the Grenadines']
# Pays en Asie : ['Bangladesh', 'China', 'Hong Kong SAR, China', 'India', 'Japan', 'Korea, Rep.', 'Sri Lanka', 'Malaysia', 'Nepal', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Turkey']
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of African countries to plot
african_countries = ['Burundi', 'Benin', 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.',
                    'Cote d\'Ivoire', 'Gabon', 'Ghana', 'Kenya', 'Lesotho', 'Madagascar', 'Morocco', 'Niger',
                    'Nigeria', 'Rwanda', 'Sudan', 'Senegal', 'Sierra Leone', 'Chad', 'Togo', 'Uganda', 'South Africa',
                    'Zambia', 'Zimbabwe']

# Restrict the DataFrame to the years from 2006 to 2022
df = df.loc['2006':'2022']

# Ensure that the columns for African countries are numeric
for country in african_countries:
    df[country] = pd.to_numeric(df[country], errors='coerce')

# Check if the conversion was successful for all African countries
if not df[african_countries].isnull().any().any():
    # Round values to two decimal places (adjust as needed)
    df[african_countries] = df[african_countries].round(2)

    # Divide all values by one billion to simplify the y-axis (display in billions of dollars)
    df[african_countries] = df[african_countries] / 1e9  # Divide by 1 billion to display in billions of dollars

    # Create a plot using the index and the variables for African countries
    plt.figure(figsize=(12, 6))

    for country in african_countries:
        plt.plot(df.index, df[country], marker='o', linestyle='-', label=country)
    plt.title(f"GDP Evolution of African Countries (2006-2022)")
    plt.xlabel("Year")
    plt.ylabel(f"GDP (in billions of dollars)")
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.grid(True)

    # Display the plot
    plt.tight_layout()
    plt.show()
else:
    print("Data conversion failed for at least one of the African countries. Please check the values in the corresponding columns.")

# %% [markdown]
# The economic evolution of Nigeria and South Africa from 2006 to the present day shows notable differences compared to other African nations.
#
# Nigeria, as the leading oil producer in Africa, has had its economy significantly influenced by the oil sector. This dependency has resulted in vulnerability to fluctuations in global oil prices, leading to periods of uneven growth. Nevertheless, Nigeria has made efforts to diversify its economy by developing sectors such as telecommunications, with companies like MTN Nigeria, and banking services.
#
# On the other hand, South Africa has maintained a diversified economy, including sectors such as mining, agriculture, finance, and tourism. While this diversification has contributed to relative economic stability, the country has faced persistent challenges such as socio-economic inequalities, high unemployment rates, and poverty issues.
#
# Furthermore, other African countries have emerged as regional economic powers. For instance, Ethiopia has become a major hub for textile and clothing production, attracting investments in manufacturing. Rwanda has focused on developing information technology and financial services, while Ghana has experienced significant growth in the oil and gas sector.
#
# The economic evolution of Nigeria and South Africa reflects the diverse paths of development and challenges faced by these two African economic giants, while other nations on the continent seek to diversify their economies and strengthen their positions on the global economic stage.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of South American countries to plot
south_american_countries = ['Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Peru', 'Suriname', 'Uruguay']

# Restrict the DataFrame to the years from 2006 to 2022
df = df.loc['2006':'2022']

# Ensure that the columns for South American countries are numeric
for country in south_american_countries:
    df[country] = pd.to_numeric(df[country], errors='coerce')

# Check if the conversion was successful for all South American countries
if not df[south_american_countries].isnull().any().any():
    # Round values to two decimal places (adjust as needed)
    df[south_american_countries] = df[south_american_countries].round(2)

    # Divide all values by one billion to simplify the y-axis (display in billions of dollars)
    df[south_american_countries] = df[south_american_countries] / 1e9  # Divide by 1 billion to display in billions of dollars

    # Create a plot using the index and the variables for South American countries
    plt.figure(figsize=(12, 6))

    # Color palette for South American countries
    south_american_colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'tab:orange', 'tab:purple', 'tab:brown',
               'tab:pink', 'tab:gray']

    for i, country in enumerate(south_american_countries):
        plt.plot(df.index, df[country], marker='o', linestyle='-', label=country, color=south_american_colors[i])

    plt.title(f"GDP Evolution of South American Countries (2006-2022)")
    plt.xlabel("Year")
    plt.ylabel(f"GDP (in billions of dollars)")
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.grid(True)

    # Display the plot
    plt.tight_layout()
    plt.show()
else:
    print("Data conversion failed for at least one of the South American countries. Please check the values in the corresponding columns.")

# %% [markdown]
# Brazil stands out as one of the most significant economies in South America, far ahead of other countries in the region in terms of size and economic potential. Its massive population, geographical diversity, and extensive natural resources make it a major economic player in South America.
#
# Brazil holds a significant portion of the region's GDP, and its economy is much larger than that of its neighbors. This is reflected in its central role as an economic engine in South America, with significant influence over regional markets, foreign investments, and trade flows.
#
# Its size and economic weight also give Brazil the capacity to influence regional economic decisions and policies. The country plays a key role in economic cooperation initiatives in South America and actively participates in regional trade agreements.
#
# However, it's important to note that despite its position as an economic leader, Brazil also faces internal challenges such as persistent socio-economic inequalities, issues of corruption, and economic fluctuations. This underscores the complexity of the economic evolution in the region and the need for Brazil to address these challenges to maintain and strengthen its leadership position in South America.
#
# The economic evolution of Brazil from 2006 to today presents a series of distinct trends compared to other countries in South America.
#
# Brazil has experienced periods of robust economic growth, primarily due to the increasing global demand for commodities such as soybeans and iron ore. However, its reliance on commodities has exposed the Brazilian economy to fluctuations in global prices, leading to periods of economic slowdown. For example, the decline in commodity prices had a negative impact on Brazilian exports.
#
# The country has also been marked by economic policies and reforms aimed at stimulating growth and investment. Labor market reforms and attempts to reduce budget deficits have been implemented to strengthen economic stability.
#
# In comparison to other South American nations, Chile has stood out for its economic stability and business-friendly policies. It has attracted foreign investments through open economic policies and a dynamic mining sector, especially in copper. Colombia, on the other hand, has experienced consistent economic growth, driven by sectors like energy and services.
#
# These economic developments reflect the complexity of economic dynamics in South America, with Brazil navigating between the highs and lows of commodity dependence while implementing reforms to promote sustainable growth.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of Asian countries to plot
asian_countries = ['China', 'India', 'Japan', 'Korea, Rep.', 'Sri Lanka', 'Hong Kong SAR, China', 'Thailand', 'Turkiye', 'Singapore', 'Malaysia', 'Pakistan', 'Nepal', 'Bangladesh', 'Philippines']

# Restrict the DataFrame to the years from 2006 to 2022
df = df.loc['2006':'2022']

# Ensure that the columns for Asian countries are numeric
for country in asian_countries:
    df[country] = pd.to_numeric(df[country], errors='coerce')

# Check if the conversion was successful for all Asian countries
if not df[asian_countries].isnull().any().any():
    # Round values to two decimal places (adjust as needed)
    df[asian_countries] = df[asian_countries].round(2)

    # Divide all values by one billion to simplify the y-axis (display in billions of dollars)
    df[asian_countries] = df[asian_countries] / 1e9  # Divide by 1 billion to display in billions of dollars

    # Create a plot using the index and the variables for Asian countries
    plt.figure(figsize=(12, 6))

    # Color palette for Asian countries
    asian_colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'tab:orange', 'tab:purple', 'tab:brown',
               'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'tab:red']

    for i, country in enumerate(asian_countries):
        plt.plot(df.index, df[country], marker='o', linestyle='-', label=country, color=asian_colors[i])

    plt.title(f"GDP Evolution of Asian Countries (2006-2022)")
    plt.xlabel("Year")
    plt.ylabel(f"GDP (in billions of dollars)")
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.grid(True)

    # Display the plot
    plt.tight_layout()
    plt.show()
else:
    print("Data conversion failed for at least one of the Asian countries. Please check the values in the corresponding columns.")

# %% [markdown]
# The economic evolution of Asia from 2006 to today has been marked by dynamic growth, with China and Japan leading the way, significantly ahead of other countries in the region.
#
# China has experienced exponential economic growth, becoming the world's second-largest economy. This rapid growth has been fueled by a massive expansion in manufacturing, exports, and technological advancements. Renowned Chinese companies such as Alibaba and Tencent have emerged as major players in the technology and online commerce sectors.
#
# A key element of China's strategy has been the Belt and Road Initiative, a vast project aimed at extending China's economic influence globally through massive investments in infrastructure abroad. This has enhanced China's economic connectivity with other regions of the world.
#
# Japan, while facing demographic challenges and slower economic growth, has remained a global leader in sectors such as automotive and electronics. Japanese companies like Toyota and Sony continue to be major players on the international stage.
#
# These two Asian economic giants have significantly contributed to the economic evolution of Asia during this period, driving growth and innovation in the region and beyond.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of European countries to plot
european_countries = ['Austria', 'Belgium', 'Finland', 'France', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Netherlands', 'Norway', 'Portugal', 'Spain', 'Sweden', 'United Kingdom']

# Restrict the DataFrame to the years from 2006 to 2022
df = df.loc['2006':'2022']

# Ensure that the columns for European countries are numeric
for country in european_countries:
    df[country] = pd.to_numeric(df[country], errors='coerce')

# Check if the conversion was successful for all European countries
if not df[european_countries].isnull().any().any():
    # Round values to two decimal places (adjust as needed)
    df[european_countries] = df[european_countries].round(2)

    # Divide all values by one billion to simplify the y-axis (display in billions of dollars)
    df[european_countries] = df[european_countries] / 1e9  # Divide by 1 billion to display in billions of dollars

    # Create a plot using the index and the variables for European countries
    plt.figure(figsize=(12, 6))

    # Color palette for European countries
    european_colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'tab:orange', 'tab:purple', 'tab:brown',
               'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'tab:red', 'tab:blue', 'tab:green',
               'tab:orange', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'tab:red']

    for i, country in enumerate(european_countries):
        plt.plot(df.index, df[country], marker='o', linestyle='-', label=country, color=european_colors[i])

    plt.title(f"GDP Evolution of European Countries (2006-2022)")
    plt.xlabel("Year")
    plt.ylabel(f"GDP (in billions of dollars)")
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.grid(True)

    # Display the plot
    plt.tight_layout()
    plt.show()
else:
    print("Data conversion failed for at least one of the European countries. Please check the values in the corresponding columns.")

# %% [markdown]
# The economic evolution of Europe from 2006 to today has been marked by a series of events and trends, with countries such as Greece, Spain, and the United Kingdom playing key roles.
#
# The global financial crisis of 2008 deeply affected Europe, with countries like Greece at the heart of the sovereign debt crisis. Financial rescue plans were necessary to stabilize struggling economies.
#
# The United Kingdom voted in favor of Brexit in 2016, triggering a process of withdrawal from the European Union that had significant economic and political consequences.
#
# The rise of political populism in countries such as Italy posed challenges to political and economic stability in Europe.
#
# The European Central Bank (ECB) implemented accommodating monetary policies to support growth, while European technology companies achieved international success, with giants like Spotify and Zalando.
#
# Europe also had to grapple with the migration crisis, managing the economic and social impact of the arrival of migrants.
#
# In parallel, the European Union entered into international trade agreements to strengthen trade, such as the CETA agreement with Canada.
#
# The economic evolution of Europe has thus been complex, marked by challenges and opportunities, with EU member countries navigating a period of growth, crises, and economic adjustments. Political and economic issues continue to shape the European region.
#
# **Greece:** Greece was at the epicenter of the European sovereign debt crisis in the late 2000s and early 2010s. The country faced a severe economic downturn, requiring multiple bailout packages from international creditors and implementing austerity measures. While it has made progress in stabilizing its finances, Greece still grapples with high public debt and economic challenges.
#
# **Spain:** Spain was another country heavily affected by the financial crisis, particularly due to a housing market collapse. In subsequent years, it implemented labor market reforms and diversified its economy, with the tourism sector playing a pivotal role in its recovery. Spain has also made significant advancements in renewable energy.
#
# **United Kingdom:** The United Kingdom's decision to leave the European Union, known as Brexit, in 2016 had profound economic and political implications. It led to years of negotiations and uncertainty, impacting trade, investments, and the value of the British pound. The UK's economic relationship with the EU continues to evolve.
#
# **France:** France maintains a mixed economy with strengths in sectors like aerospace, fashion, and automobiles. The country has been active in promoting European defense and security cooperation and is a key player in the European Union.
#
# **Italy:** Italy has faced economic and political challenges, including a high public debt and slow economic growth. Internal political tensions and concerns about financial stability have contributed to Italy's complex economic landscape.
#
# **Netherlands:** The Netherlands has sustained an open and trade-oriented economy, with strengths in agriculture, logistics, and technology. The country has attracted multinational corporations due to its favorable business environment.
#
# These European countries have navigated a dynamic economic landscape marked by global financial crises, political shifts, and regional challenges. Their individual experiences illustrate the diversity of economic trajectories within the broader European context.
